# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaf0014/customer-segmentation-project/blob/main/week2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating data set

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
    {
        "CustomerID": range(1001, 1141),  # 140 Customer IDs
        "Age": np.random.randint(18, 65, 140),  # Ages 18 to 65
        "Income": np.random.randint(20, 120, 140),  # Income ($k)
        "SpendingScore": np.random.randint(1, 100, 140),  # Score 1-100
    }
)

print(f"Dataset shape: {df.shape}")  # Outputs (140, 4)
print(df)
# Out:
# Dataset shape: (140, 4)
#      CustomerID  Age  Income  SpendingScore
# 0          1001   25      78             68
# 1          1002   61     110             98
# 2          1003   60      44             39
# 3          1004   23      90             73
# 4          1005   37      72             41
# ..          ...  ...     ...            ...
# 135        1136   36      99             61
# 136        1137   26      48             23
# 137        1138   57      94              8
# 138        1139   61      21             76
# 139        1140   48      97             16
#
# [140 rows x 4 columns]

# %%
from sklearn.cluster import KMeans

X = df[["Income","SpendingScore"]]

model = KMeans(n_clusters=5, random_state=42)
df["Cluster"] = model.fit_predict(X)
print(df)
# Out:
#      CustomerID  Age  Income  SpendingScore  Cluster
# 0          1001   25      78             68        1
# 1          1002   61     110             98        4
# 2          1003   60      44             39        2
# 3          1004   23      90             73        1
# 4          1005   37      72             41        1
# ..          ...  ...     ...            ...      ...
# 135        1136   36      99             61        1
# 136        1137   26      48             23        2
# 137        1138   57      94              8        3
# 138        1139   61      21             76        0
# 139        1140   48      97             16        3
#
# [140 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Income"], df["SpendingScore"], c=df["Cluster"], cmap="viridis")

plt.xlabel("Annual Income ($k)")
plt.ylabel("Spending Score (1-100)")
plt.title("Customer Segments (140 Customers)")
plt.colorbar(label="Cluster Group")
plt.show()
